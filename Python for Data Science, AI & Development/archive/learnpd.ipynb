# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
file = R"/home/sparkm/Documents/AIML/Python for Data Science, AI & Development/archive/data.csv"

pd.read_csv(file)
df = pd.read_csv(file)
pd.DataFrame(df)
# Out:
#                      date         price  bedrooms  bathrooms  sqft_living  \
# 0     2014-05-02 00:00:00  3.130000e+05       3.0       1.50         1340
# 1     2014-05-02 00:00:00  2.384000e+06       5.0       2.50         3650
# 2     2014-05-02 00:00:00  3.420000e+05       3.0       2.00         1930
# 3     2014-05-02 00:00:00  4.200000e+05       3.0       2.25         2000
# 4     2014-05-02 00:00:00  5.500000e+05       4.0       2.50         1940
# ...                   ...           ...       ...        ...          ...
# 4595  2014-07-09 00:00:00  3.081667e+05       3.0       1.75         1510
# 4596  2014-07-09 00:00:00  5.343333e+05       3.0       2.50         1460
# 4597  2014-07-09 00:00:00  4.169042e+05       3.0       2.50         3010
# 4598  2014-07-10 00:00:00  2.034000e+05       4.0       2.00         2090
# 4599  2014-07-10 00:00:00  2.206000e+05       3.0       2.50         1490
#
#       sqft_lot  floors  waterfront  view  condition  sqft_above  \
# ...

# %%
pd.DataFrame(df[['price']])
# Out:
#              price
# 0     3.130000e+05
# 1     2.384000e+06
# 2     3.420000e+05
# 3     4.200000e+05
# 4     5.500000e+05
# ...            ...
# 4595  3.081667e+05
# 4596  5.343333e+05
# 4597  4.169042e+05
# 4598  2.034000e+05
# 4599  2.206000e+05
#
# [4600 rows x 1 columns]

# %%
rooms = pd.unique(df['bedrooms'])
print(rooms)
# Out:
# [3. 5. 4. 2. 6. 7. 9. 1. 8. 0.]

# %%
a = df['bedrooms'].value_counts()
a
# Out:
# bedrooms
# 3.0    2032
# 4.0    1531
# 2.0     566
# 5.0     353
# 6.0      61
# 1.0      38
# 7.0      14
# 8.0       2
# 0.0       2
# 9.0       1
# Name: count, dtype: int64

# %%
df1 = df[df['bedrooms'])]
df1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 df1 = df[int(df['bedrooms'])]
#       2 df1
#
# File ~/.local/lib/python3.12/site-packages/pandas/core/series.py:248, in _coerce_method.<locals>.wrapper(self)
#     240     warnings.warn(
#     241         f"Calling {converter.__name__} on a single element Series is "
#     242         "deprecated and will raise a TypeError in the future. "
#    (...)
#     245         stacklevel=find_stack_level(),
#     246     )
#     247     return converter(self.iloc[0])
# --> 248 raise TypeError(f"cannot convert the series to {converter}")
#
# TypeError: cannot convert the series to <class 'int'>

# %%
x_data = df['bedrooms']
y_data = df['price']

plt.title('Price vs Bedrooms')
plt.boxplot(y_data, x_data)
# plt.scatter(x_data, y_data, color='blue')
plt.xlabel('Bedrooms')
plt.ylabel('Price')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_10427/1307104653.py in ?()
#       1 x_data = df['bedrooms']
#       2 y_data = df['price']
#       3
#       4 plt.title('Price vs Bedrooms')
# ----> 5 plt.boxplot(y_data, x_data)
#       6 # plt.scatter(x_data, y_data, color='blue')
#       7 plt.xlabel('Bedrooms')
#       8 plt.ylabel('Price')
#
# ~/.local/lib/python3.12/site-packages/matplotlib/_api/deprecation.py in ?(*args, **kwargs)
#     296                 since, message=f"The {old!r} parameter of {func.__name__}() "
#     297                 f"has been renamed {new!r} since Matplotlib {since}; support "
#     298                 f"for the old name will be dropped %(removal)s.")
#     299             kwargs[new] = kwargs.pop(old)
# --> 300         return func(*args, **kwargs)
#
# ...
